# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_shampo_sales = pd.read_csv('shampo_sales.csv')
df_shampo_sales.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
plt.figure(figsize=(16,4))
sns.lineplot(
    data=df_shampo_sales,
    x='Month',
    y='Sales'
)
plt.show()

# %%
df_shampo_sales[12:24]
# Out:
#    Month  Sales
# 12  2-01  194.3
# 13  2-02  149.5
# 14  2-03  210.1
# 15  2-04  273.3
# 16  2-05  191.4
# 17  2-06  287.0
# 18  2-07  226.0
# 19  2-08  303.6
# 20  2-09  289.9
# 21  2-10  421.6
# 22  2-11  264.5
# 23  2-12  342.3
